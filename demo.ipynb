# %%
from metrics import calculate_entropy
from metrics import calculate_uciqe
from metrics import calculate_uiqm
import os 

def analysis(root_dir):
    # 一级子目录（算法名称）
    algorithms = ['COLOR', 'FGAN', 'FUSION2', 'OURS', 'RGHS', 'UDCP', 'UGAN', 'ULAP']

    total_entropy = 0.0
    total_count = 0

    # 用于存储每个算法的熵和计数
    algo_stats = {alg: {'sum': 0.0, 'count': 0} for alg in algorithms}

    for alg in algorithms:
        alg_dir = os.path.join(root_dir, alg)
        if not os.path.isdir(alg_dir):
            print(f"警告：未找到目录 {alg_dir}，跳过。")
            continue

        # 直接遍历一级目录下的所有文件
        for fname in os.listdir(alg_dir):
            file_path = os.path.join(alg_dir, fname)
            # 只处理文件且后缀为图片格式
            if not os.path.isfile(file_path):
                continue
            if not fname.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff', '.gif')):
                continue

            try:
                e = calculate_entropy(file_path)
            except Exception as ex:
                print(f"无法处理 {file_path}：{ex}")
                continue

            algo_stats[alg]['sum'] += e
            algo_stats[alg]['count'] += 1
            total_entropy += e
            total_count += 1

    # 输出总体平均熵
    if total_count > 0:
        print(f"\n所有算法所有图片的总体平均熵：{total_entropy/total_count:.4f}")
    else:
        print("\n未找到任何图片。")

    # 输出各算法平均熵
    print("\n各算法平均熵：")
    for alg in algorithms:
        cnt = algo_stats[alg]['count']
        if cnt > 0:
            avg = algo_stats[alg]['sum'] / cnt
            print(f"  {alg:7s} ：{avg:.4f} （共 {cnt} 张图）")
        else:
            print(f"  {alg:7s} ：未找到图片")

analysis('/media/users/leo/workspace/UIE/expri/UIDEF_S')
# Out:
# 所有算法所有图片的总体平均熵：7.0632
#
# 各算法平均熵：
#   COLOR   ：7.5387 （共 164 张图）
#   FGAN    ：6.7357 （共 164 张图）
#   FUSION2 ：7.7668 （共 164 张图）
#   OURS    ：7.5467 （共 164 张图）
#   RGHS    ：6.5164 （共 164 张图）
#   UDCP    ：6.3683 （共 164 张图）
#   UGAN    ：6.9406 （共 164 张图）
#   ULAP    ：7.0923 （共 164 张图）

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os
import sys
from PIL import Image
import numpy as np

def calculate_entropy(image_path):
    """
    计算单张灰度图像的香农熵：
      H = -∑ p(i) log2 p(i)
    """
    img = Image.open(image_path).convert('L')
    hist = np.array(img.histogram(), dtype=np.float64)
    p = hist / hist.sum()
    p = p[p > 0]
    return -np.sum(p * np.log2(p))

def main(dir1, dir2):
    # 支持的图片后缀
    exts = ('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff', '.gif')
    # 结果列表
    higher_in_dir2 = []

    # 枚举 dir1 中的图片文件
    for fname in os.listdir(dir1):
        if not fname.lower().endswith(exts):
            continue

        path1 = os.path.join(dir1, fname)
        path2 = os.path.join(dir2, fname)

        # 只处理在 dir2 中也存在同名文件的情况
        if not os.path.isfile(path2):
            continue

        try:
            e1 = calculate_entropy(path1)
            e2 = calculate_entropy(path2)
        except Exception as ex:
            print(f"无法处理 {fname}：{ex}")
            continue

        # 如果 dir_2 的熵更大，则加入列表
        if e2 > e1:
            higher_in_dir2.append(fname)

    # 打印结果
    if higher_in_dir2:
        print("以下图片在 dir_2 中的熵高于 dir_1：")
        for name in higher_in_dir2:
            print(f"  {name}")
    else:
        print("没有找到在 dir_2 中熵更高的同名图片。")

if __name__ == '__main__':
    # if len(sys.argv) != 3:
    #     print("用法: python compare_entropy.py <dir_1> <dir_2>")
    #     sys.exit(1)

    dir_1 = '/media/users/leo/workspace/UIE/expri/UIEB/FUSION2'
    dir_2 = '/media/users/leo/workspace/UIE/expri/UIEB/OURS'

    if not os.path.isdir(dir_1) or not os.path.isdir(dir_2):
        print("错误：请确保两个参数都是已存在的目录。")
        sys.exit(1)

    main(dir_1, dir_2)
# Out:
# 以下图片在 dir_2 中的熵高于 dir_1：
#   2629.png
#   789_img_.png
#   9_img_.png
#   534_img_.png
#   614_img_.png
#   155_img_.png
#   696_img_.png
#   12324.png
#   332_img_.png
#   682_img_.png
#   793_img_.png
#   880_img_.png
#   767_img_.png
#   451_img_.png
#   15426.png
#   287_img_.png
#   917_img_.png
#   1573.png
#   12348.png
#   320_img_.png
#   555_img_.png
#   400_img_.png
#   765_img_.png
#   53_img_.png
#   366_img_.png
#   834_img_.png
#   1660.png
#   531_img_.png
#   225_img_.png
#   611_img_.png
#   12290.png
#   111_img_.png
#   913_img_.png
#   491_img_.png
#   715_img_.png
#   632_img_.png
#   923_img_.png
#   869_img_.png
#   580_img_.png
#   661_img_.png
#   709_img_.png
#   625_img_.png
#   160_img_.png
#   221_img_.png
#   615_img_.png
#   385_img_.png
#   140_img_.png
#   100_img_.png
#   306_img_.png
#   763_img_.png
#   798_img_.png
#   918_img_.png
#   290_img_.png
#   294_img_.png
#   258_img_.png
#   893_img_.png
#   841.png
#   784_img_.png
#   315_img_.png

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

def calculate_entropy(image_path):
    img = Image.open(image_path).convert('L')
    hist = np.array(img.histogram(), dtype=np.float64)
    p = hist / hist.sum()
    p = p[p > 0]
    return -np.sum(p * np.log2(p))

dir1 = '/media/users/leo/workspace/UIE/expri/UIEB/FUSION2'
dir2 = '/media/users/leo/workspace/UIE/expri/UIEB/OURS'

exts = ('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff', '.gif')
common = [f for f in os.listdir(dir1) if f.lower().endswith(exts) and os.path.isfile(os.path.join(dir2, f))]

output_dir = 'tmp/'

for fname in common:
    path1 = os.path.join(dir1, fname)
    path2 = os.path.join(dir2, fname)
    e1 = calculate_entropy(path1)
    e2 = calculate_entropy(path2)
    print('processing...', fname)
    if e2 > e1:
    
        fig, axes = plt.subplots(1, 2, figsize=(10, 5))
        axes[0].imshow(Image.open(path1))
        axes[0].set_title(f"{fname} (FUSION2) entropy={e1:.4f}")
        axes[0].axis('off')
        axes[1].imshow(Image.open(path2))
        axes[1].set_title(f"{fname} (OURS) entropy={e2:.4f}")
        axes[1].axis('off')
        plt.tight_layout()
        
        # 保存图像到 output_dir，文件名保持一致
        save_path = os.path.join(output_dir, fname)
        fig.savefig(save_path, bbox_inches='tight')
        plt.close(fig)

# for fname in common:
#     path1 = os.path.join(dir1, fname)
#     path2 = os.path.join(dir2, fname)
#     e1 = calculate_entropy(path1)
#     e2 = calculate_entropy(path2)
#     print('processing...', fname)
#     if e2 > e1:
#         fig, axes = plt.subplots(1, 2, figsize=(10, 5))
#         axes[0].imshow(Image.open(path1))
#         axes[0].set_title(f"{fname} (FUSION2) entropy={e1:.4f}")
#         axes[0].axis('off')
#         axes[1].imshow(Image.open(path2))
#         axes[1].set_title(f"{fname} (OURS) entropy={e2:.4f}")
#         axes[1].axis('off')
#         plt.tight_layout()
#         plt.show()
# Out:
# processing... 130_img_.png
# processing... 926_img_.png
# processing... 2629.png
# processing... 108_img_.png
# processing... 5554.png
# processing... 80_img_.png
# processing... 929_img_.png
# processing... 374_img_.png
# processing... 285_img_.png
# processing... 341_img_.png
# processing... 312_img_.png
# processing... 789_img_.png
# processing... 173_img_.png
# processing... 652_img_.png
# processing... 9_img_.png
# processing... 386_img_.png
# processing... 768_img_.png
# processing... 45_img_.png
# processing... 769_img_.png
# processing... 673_img_.png
# processing... 115_img_.png
# processing... 32_img_.png
# processing... 802_img_.png
# processing... 657_img_.png
# processing... 11052.png
# processing... 719_img_.png
# processing... 12445.png
# processing... 849_img_.png
# processing... 509_img_.png
# processing... 6788.png
# processing... 817_img_.png
# processing... 64_img_.png
# processing... 503_img_.png
# processing... 819_img_.png
# processing... 843_img_.png
# processing... 776_img_.png
# processing... 89_img_.png
# processing... 245_img_.png
# processing... 1407.png
# processing... 479_img_.png
# processing... 381_img_.png
# processing... 210_img_.png
# processing... 151_img_.png
# processing... 370_img_.png
# processing... 646_img_.png
# processing... 10_img_.png
# processing... 343_img_.png
# processing... 757_img_.png
# processing... 6082.png
# processing... 598_img_.png
# processing... 7654.png
# processing... 527_img_.png
# processing... 663_img_.png
# processing... 687_img_.png
# processing... 340_img_.png
# processing... 837_img_.png
# processing... 254_img_.png
# processing... 288_img_.png
# processing... 534_img_.png
# processing... 437_img_.png
# processing... 718_img_.png
# processing... 162_img_.png
# processing... 850_img_.png
# processing... 808_img_.png
# processing... 463_img_.png
# processing... 686_img_.png
# processing... 865_img_.png
# processing... 874_img_.png
# processing... 804_img_.png
# processing... 640_img_.png
# processing... 314_img_.png
# processing... 24_img_.png
# processing... 419_img_.png
# processing... 303_img_.png
# processing... 171_img_.png
# processing... 409_img_.png
# processing... 654_img_.png
# processing... 156_img_.png
# processing... 10139.png
# processing... 614_img_.png
# processing... 868_img_.png
# processing... 364_img_.png
# processing... 698_img_.png
# processing... 536_img_.png
# processing... 579_img_.png
# processing... 779_img_.png
# processing... 924_img_.png
# processing... 175_img_.png
# processing... 543_img_.png
# processing... 877_img_.png
# processing... 603_img_.png
# processing... 459_img_.png
# processing... 136_img_.png
# processing... 666_img_.png
# processing... 910_img_.png
# processing... 720_img_.png
# processing... 645_img_.png
# processing... 562_img_.png
# processing... 96_img_.png
# processing... 9557.png
# processing... 30_img_.png
# processing... 109_img_.png
# processing... 196_img_.png
# processing... 572_img_.png
# processing... 42_img_.png
# processing... 261_img_.png
# processing... 155_img_.png
# processing... 168_img_.png
# processing... 734_img_.png
# processing... 452_img_.png
# processing... 67_img_.png
# processing... 17_img_.png
# processing... 138_img_.png
# processing... 574_img_.png
# processing... 482_img_.png
# processing... 759_img_.png
# processing... 220_img_.png
# processing... 508_img_.png
# processing... 322_img_.png
# processing... 887_img_.png
# processing... 771_img_.png
# processing... 557_img_.png
# processing... 702_img_.png
# processing... 841_img_.png
# processing... 890_img_.png
# processing... 158_img_.png
# processing... 696_img_.png
# processing... 711_img_.png
# processing... 146_img_.png
# processing... 927_img_.png
# processing... 901_img_.png
# processing... 12299.png
# processing... 775_img_.png
# processing... 12324.png
# processing... 796_img_.png
# processing... 813_img_.png
# processing... 9947.png
# processing... 193_img_.png
# processing... 139_img_.png
# processing... 8056.png
# processing... 679_img_.png
# processing... 296_img_.png
# processing... 332_img_.png
# processing... 639_img_.png
# processing... 5830.png
# processing... 230_img_.png
# processing... 563.png
# processing... 104_img_.png
# processing... 612_img_.png
# processing... 727_img_.png
# processing... 855_img_.png
# processing... 295_img_.png
# processing... 751_img_.png
# processing... 2774.png
# processing... 10945.png
# processing... 56_img_.png
# processing... 298_img_.png
# processing... 15001.png
# processing... 454_img_.png
# processing... 421_img_.png
# processing... 823_img_.png
# processing... 51_img_.png
# processing... 689_img_.png
# processing... 591_img_.png
# processing... 330_img_.png
# processing... 682_img_.png
# processing... 803_img_.png
# processing... 404_img_.png
# processing... 532_img_.png
# processing... 539_img_.png
# processing... 90_img_.png
# processing... 15094.png
# processing... 489_img_.png
# processing... 353_img_.png
# processing... 443_img_.png
# processing... 707_img_.png
# processing... 782_img_.png
# processing... 809_img_.png
# processing... 714_img_.png
# processing... 11064.png
# processing... 800_img_.png
# processing... 113_img_.png
# processing... 480_img_.png
# processing... 201_img_.png
# processing... 516_img_.png
# processing... 8262.png
# processing... 793_img_.png
# processing... 382_img_.png
# processing... 880_img_.png
# processing... 450_img_.png
# processing... 767_img_.png
# processing... 440_img_.png
# processing... 589_img_.png
# processing... 418_img_.png
# processing... 816_img_.png
# processing... 828_img_.png
# processing... 699_img_.png
# processing... 412_img_.png
# processing... 556_img_.png
# processing... 199_img_.png
# processing... 889_img_.png
# processing... 362_img_.png
# processing... 662_img_.png
# processing... 98_img_.png
# processing... 10151.png
# processing... 122_img_.png
# processing... 633_img_.png
# processing... 301_img_.png
# processing... 3728.png
# processing... 477_img_.png
# processing... 807_img_.png
# processing... 497_img_.png
# processing... 676_img_.png
# processing... 584_img_.png
# processing... 495_img_.png
# processing... 551_img_.png
# processing... 647_img_.png
# processing... 706_img_.png
# processing... 94_img_.png
# processing... 246_img_.png
# processing... 278_img_.png
# processing... 528_img_.png
# processing... 637_img_.png
# processing... 770_img_.png
# processing... 275_img_.png
# processing... 217_img_.png
# processing... 735_img_.png
# processing... 620_img_.png
# processing... 206_img_.png
# processing... 451_img_.png
# processing... 95_img_.png
# processing... 465_img_.png
# processing... 501_img_.png
# processing... 716_img_.png
# processing... 240_img_.png
# processing... 723_img_.png
# processing... 15426.png
# processing... 485_img_.png
# processing... 867_img_.png
# processing... 502_img_.png
# processing... 610_img_.png
# processing... 253_img_.png
# processing... 7916.png
# processing... 875_img_.png
# processing... 4_img_.png
# processing... 209_img_.png
# processing... 223_img_.png
# processing... 545_img_.png
# processing... 797_img_.png
# processing... 207_img_.png
# processing... 212_img_.png
# processing... 605_img_.png
# processing... 725_img_.png
# processing... 766_img_.png
# processing... 9554.png
# processing... 3947.png
# processing... 112_img_.png
# processing... 2677.png
# processing... 144_img_.png
# processing... 6872.png
# processing... 708_img_.png
# processing... 578_img_.png
# processing... 20.png
# processing... 187_img_.png
# processing... 549_img_.png
# processing... 455_img_.png
# processing... 672_img_.png
# processing... 710_img_.png
# processing... 677_img_.png
# processing... 810_img_.png
# processing... 916_img_.png
# processing... 499_img_.png
# processing... 50_img_.png
# processing... 581_img_.png
# processing... 799_img_.png
# processing... 183_img_.png
# processing... 684_img_.png
# processing... 861_img_.png
# processing... 205_img_.png
# processing... 163_img_.png
# processing... 490_img_.png
# processing... 7643.png
# processing... 106_img_.png
# processing... 422_img_.png
# processing... 268_img_.png
# processing... 832_img_.png
# processing... 691_img_.png
# processing... 219_img_.png
# processing... 241_img_.png
# processing... 9547.png
# processing... 7_img_.png
# processing... 471_img_.png
# processing... 488_img_.png
# processing... 613_img_.png
# processing... 213_img_.png
# processing... 287_img_.png
# processing... 279_img_.png
# processing... 299_img_.png
# processing... 772_img_.png
# processing... 917_img_.png
# processing... 494_img_.png
# processing... 701_img_.png
# processing... 37_img_.png
# processing... 444_img_.png
# processing... 1573.png
# processing... 649_img_.png
# processing... 680_img_.png
# processing... 55_img_.png
# processing... 540_img_.png
# processing... 597_img_.png
# processing... 602_img_.png
# processing... 87_img_.png
# processing... 685_img_.png
# processing... 436_img_.png
# processing... 891_img_.png
# processing... 788_img_.png
# processing... 328_img_.png
# processing... 391_img_.png
# processing... 604_img_.png
# processing... 814_img_.png
# processing... 794_img_.png
# processing... 8046.png
# processing... 272_img_.png
# processing... 890.png
# processing... 11374.png
# processing... 628_img_.png
# processing... 847_img_.png
# processing... 420_img_.png
# processing... 519_img_.png
# processing... 377_img_.png
# processing... 790_img_.png
# processing... 228_img_.png
# processing... 787_img_.png
# processing... 12348.png
# processing... 15418.png
# processing... 320_img_.png
# processing... 72_img_.png
# processing... 833_img_.png
# processing... 555_img_.png
# processing... 22_img_.png
# processing... 566_img_.png
# processing... 400_img_.png
# processing... 568_img_.png
# processing... 590_img_.png
# processing... 365_img_.png
# processing... 234_img_.png
# processing... 410_img_.png
# processing... 634_img_.png
# processing... 630_img_.png
# processing... 557.png
# processing... 39_img_.png
# processing... 765_img_.png
# processing... 746_img_.png
# processing... 53_img_.png
# processing... 498_img_.png
# processing... 587_img_.png
# processing... 2977.png
# processing... 4070.png
# processing... 838_img_.png
# processing... 336_img_.png
# processing... 28_img_.png
# processing... 131_img_.png
# processing... 188_img_.png
# processing... 31.png
# processing... 683_img_.png
# processing... 366_img_.png
# processing... 806_img_.png
# processing... 123_img_.png
# processing... 15544.png
# processing... 74_img_.png
# processing... 822_img_.png
# processing... 248_img_.png
# processing... 736_img_.png
# processing... 379_img_.png
# processing... 476_img_.png
# processing... 176_img_.png
# processing... 8288.png
# processing... 834_img_.png
# processing... 1660.png
# processing... 919_img_.png
# processing... 423_img_.png
# processing... 635_img_.png
# processing... 48_img_.png
# processing... 468_img_.png
# processing... 318_img_.png
# processing... 337_img_.png
# processing... 863_img_.png
# processing... 460_img_.png
# processing... 842_img_.png
# processing... 531_img_.png
# processing... 169_img_.png
# processing... 756.png
# processing... 648_img_.png
# processing... 438_img_.png
# processing... 225_img_.png
# processing... 226_img_.png
# processing... 416_img_.png
# processing... 114_img_.png
# processing... 383_img_.png
# processing... 179_img_.png
# processing... 203_img_.png
# processing... 651_img_.png
# processing... 281_img_.png
# processing... 276_img_.png
# processing... 600_img_.png
# processing... 703_img_.png
# processing... 367_img_.png
# processing... 154_img_.png
# processing... 846_img_.png
# processing... 59_img_.png
# processing... 190_img_.png
# processing... 607_img_.png
# processing... 493_img_.png
# processing... 15704.png
# processing... 611_img_.png
# processing... 906_img_.png
# processing... 510_img_.png
# processing... 345_img_.png
# processing... 896_img_.png
# processing... 145_img_.png
# processing... 355_img_.png
# processing... 5818.png
# processing... 907_img_.png
# processing... 242_img_.png
# processing... 472_img_.png
# processing... 270_img_.png
# processing... 116_img_.png
# processing... 57_img_.png
# processing... 403_img_.png
# processing... 319_img_.png
# processing... 866_img_.png
# processing... 184_img_.png
# processing... 373_img_.png
# processing... 546_img_.png
# processing... 172_img_.png
# processing... 786_img_.png
# processing... 3001.png
# processing... 61_img_.png
# processing... 733_img_.png
# processing... 148_img_.png
# processing... 433_img_.png
# processing... 674_img_.png
# processing... 811_img_.png
# processing... 77_img_.png
# processing... 11398.png
# processing... 266_img_.png
# processing... 678_img_.png
# processing... 307_img_.png
# processing... 170_img_.png
# processing... 697_img_.png
# processing... 756_img_.png
# processing... 161_img_.png
# processing... 750_img_.png
# processing... 461_img_.png
# processing... 380_img_.png
# processing... 925_img_.png
# processing... 829_img_.png
# processing... 12290.png
# processing... 862_img_.png
# processing... 49_img_.png
# processing... 544_img_.png
# processing... 324_img_.png
# processing... 348_img_.png
# processing... 111_img_.png
# processing... 815_img_.png
# processing... 200_img_.png
# processing... 338_img_.png
# processing... 593_img_.png
# processing... 467_img_.png
# processing... 73_img_.png
# processing... 748_img_.png
# processing... 243_img_.png
# processing... 387_img_.png
# processing... 12422.png
# processing... 62_img_.png
# processing... 835_img_.png
# processing... 15_img_.png
# processing... 293_img_.png
# processing... 356_img_.png
# processing... 558_img_.png
# processing... 13_img_.png
# processing... 724_img_.png
# processing... 189_img_.png
# processing... 232_img_.png
# processing... 101_img_.png
# processing... 441_img_.png
# processing... 585_img_.png
# processing... 191_img_.png
# processing... 216_img_.png
# processing... 389_img_.png
# processing... 878_img_.png
# processing... 10909.png
# processing... 227_img_.png
# processing... 202_img_.png
# processing... 6_img_.png
# processing... 4.png
# processing... 586_img_.png
# processing... 913_img_.png
# processing... 622_img_.png
# processing... 137_img_.png
# processing... 375_img_.png
# processing... 871_img_.png
# processing... 257_img_.png
# processing... 12433.png
# processing... 752_img_.png
# processing... 208_img_.png
# processing... 670_img_.png
# processing... 19_img_.png
# processing... 316_img_.png
# processing... 656_img_.png
# processing... 491_img_.png
# processing... 732_img_.png
# processing... 712_img_.png
# processing... 547_img_.png
# processing... 879_img_.png
# processing... 1539.png
# processing... 653_img_.png
# processing... 641_img_.png
# processing... 642_img_.png
# processing... 369_img_.png
# processing... 542_img_.png
# processing... 360_img_.png
# processing... 3_img_.png
# processing... 82_img_.png
# processing... 601_img_.png
# processing... 741_img_.png
# processing... 125_img_.png
# processing... 695_img_.png
# processing... 129_img_.png
# processing... 14_img_.png
# processing... 858_img_.png
# processing... 856_img_.png
# processing... 251_img_.png
# processing... 229_img_.png
# processing... 515_img_.png
# processing... 457_img_.png
# processing... 844_img_.png
# processing... 726_img_.png
# processing... 785_img_.png
# processing... 435_img_.png
# processing... 60_img_.png
# processing... 599_img_.png
# processing... 224_img_.png
# processing... 107_img_.png
# processing... 411_img_.png
# processing... 442_img_.png
# processing... 524_img_.png
# processing... 236_img_.png
# processing... 552_img_.png
# processing... 7027.png
# processing... 851_img_.png
# processing... 827_img_.png
# processing... 651.png
# processing... 539.png
# processing... 263_img_.png
# processing... 428_img_.png
# processing... 623_img_.png
# processing... 715_img_.png
# processing... 632_img_.png
# processing... 721_img_.png
# processing... 166_img_.png
# processing... 758.png
# processing... 86_img_.png
# processing... 780_img_.png
# processing... 2546.png
# processing... 636_img_.png
# processing... 762_img_.png
# processing... 923_img_.png
# processing... 588_img_.png
# processing... 304_img_.png
# processing... 596_img_.png
# processing... 869_img_.png
# processing... 58_img_.png
# processing... 432_img_.png
# processing... 700_img_.png
# processing... 402_img_.png
# processing... 185_img_.png
# processing... 3330.png
# processing... 569_img_.png
# processing... 860_img_.png
# processing... 626_img_.png
# processing... 407_img_.png
# processing... 192_img_.png
# processing... 705_img_.png
# processing... 260_img_.png
# processing... 3015.png
# processing... 347_img_.png
# processing... 9896.png
# processing... 729_img_.png
# processing... 530_img_.png
# processing... 912_img_.png
# processing... 16_img_.png
# processing... 580_img_.png
# processing... 118_img_.png
# processing... 744_img_.png
# processing... 537_img_.png
# processing... 690_img_.png
# processing... 781_img_.png
# processing... 274_img_.png
# processing... 895_img_.png
# processing... 661_img_.png
# processing... 346_img_.png
# processing... 44_img_.png
# processing... 292_img_.png
# processing... 777_img_.png
# processing... 550_img_.png
# processing... 561_img_.png
# processing... 394_img_.png
# processing... 881_img_.png
# processing... 484_img_.png
# processing... 2_img_.png
# processing... 105_img_.png
# processing... 538_img_.png
# processing... 52_img_.png
# processing... 709_img_.png
# processing... 27_img_.png
# processing... 506_img_.png
# processing... 300_img_.png
# processing... 507_img_.png
# processing... 174_img_.png
# processing... 15003.png
# processing... 150_img_.png
# processing... 511_img_.png
# processing... 848_img_.png
# processing... 625_img_.png
# processing... 152_img_.png
# processing... 533_img_.png
# processing... 415_img_.png
# processing... 164_img_.png
# processing... 692_img_.png
# processing... 1957.png
# processing... 8010.png
# processing... 160_img_.png
# processing... 792_img_.png
# processing... 23_img_.png
# processing... 638_img_.png
# processing... 15045.png
# processing... 401_img_.png
# processing... 704_img_.png
# processing... 214_img_.png
# processing... 791_img_.png
# processing... 845_img_.png
# processing... 376_img_.png
# processing... 820_img_.png
# processing... 837.png
# processing... 852_img_.png
# processing... 921_img_.png
# processing... 325_img_.png
# processing... 688_img_.png
# processing... 812_img_.png
# processing... 606_img_.png
# processing... 238_img_.png
# processing... 9907.png
# processing... 560_img_.png
# processing... 486_img_.png
# processing... 271_img_.png
# processing... 221_img_.png
# processing... 909_img_.png
# processing... 284_img_.png
# processing... 384_img_.png
# processing... 447_img_.png
# processing... 351_img_.png
# processing... 247_img_.png
# processing... 481_img_.png
# processing... 668_img_.png
# processing... 615_img_.png
# processing... 12900.png
# processing... 439_img_.png
# processing... 675_img_.png
# processing... 211_img_.png
# processing... 2787.png
# processing... 323_img_.png
# processing... 462_img_.png
# processing... 2882.png
# processing... 385_img_.png
# processing... 905_img_.png
# processing... 619_img_.png
# processing... 876_img_.png
# processing... 621_img_.png
# processing... 483_img_.png
# processing... 575_img_.png
# processing... 41_img_.png
# processing... 492_img_.png
# processing... 859_img_.png
# processing... 102_img_.png
# processing... 97_img_.png
# processing... 722_img_.png
# processing... 9900.png
# processing... 758_img_.png
# processing... 35.png
# processing... 140_img_.png
# processing... 277_img_.png
# processing... 737_img_.png
# processing... 518_img_.png
# processing... 43_img_.png
# processing... 783_img_.png
# processing... 576_img_.png
# processing... 872_img_.png
# processing... 892_img_.png
# processing... 908_img_.png
# processing... 618_img_.png
# processing... 25_img_.png
# processing... 464_img_.png
# processing... 120_img_.png
# processing... 327_img_.png
# processing... 302_img_.png
# processing... 911_img_.png
# processing... 749_img_.png
# processing... 753_img_.png
# processing... 92_img_.png
# processing... 592_img_.png
# processing... 3925.png
# processing... 405_img_.png
# processing... 159_img_.png
# processing... 311_img_.png
# processing... 1742.png
# processing... 505_img_.png
# processing... 334_img_.png
# processing... 372_img_.png
# processing... 12336.png
# processing... 517_img_.png
# processing... 198_img_.png
# processing... 513_img_.png
# processing... 466_img_.png
# processing... 595_img_.png
# processing... 165_img_.png
# processing... 6062.png
# processing... 408_img_.png
# processing... 15136.png
# processing... 79_img_.png
# processing... 730_img_.png
# processing... 273_img_.png
# processing... 564_img_.png
# processing... 760_img_.png
# processing... 795_img_.png
# processing... 6820.png
# processing... 821_img_.png
# processing... 46_img_.png
# processing... 567_img_.png
# processing... 571_img_.png
# processing... 100_img_.png
# processing... 713_img_.png
# processing... 306_img_.png
# processing... 660_img_.png
# processing... 747_img_.png
# processing... 305_img_.png
# processing... 583_img_.png
# processing... 350_img_.png
# processing... 3202.png
# processing... 133_img_.png
# processing... 395_img_.png
# processing... 554_img_.png
# processing... 773_img_.png
# processing... 3196.png
# processing... 598.png
# processing... 740_img_.png
# processing... 413_img_.png
# processing... 15113.png
# processing... 252_img_.png
# processing... 70_img_.png
# processing... 904_img_.png
# processing... 487_img_.png
# processing... 658_img_.png
# processing... 371_img_.png
# processing... 763_img_.png
# processing... 280_img_.png
# processing... 282_img_.png
# processing... 914_img_.png
# processing... 157_img_.png
# processing... 541_img_.png
# processing... 153_img_.png
# processing... 798_img_.png
# processing... 393_img_.png
# processing... 194_img_.png
# processing... 512_img_.png
# processing... 928_img_.png
# processing... 453_img_.png
# processing... 918_img_.png
# processing... 627_img_.png
# processing... 76_img_.png
# processing... 473_img_.png
# processing... 267_img_.png
# processing... 616_img_.png
# processing... 582_img_.png
# processing... 659_img_.png
# processing... 65_img_.png
# processing... 608_img_.png
# processing... 255_img_.png
# processing... 9567.png
# processing... 496_img_.png
# processing... 731_img_.png
# processing... 91_img_.png
# processing... 448_img_.png
# processing... 313_img_.png
# processing... 262_img_.png
# processing... 458_img_.png
# processing... 754_img_.png
# processing... 26_img_.png
# processing... 526_img_.png
# processing... 215_img_.png
# processing... 629_img_.png
# processing... 244_img_.png
# processing... 29_img_.png
# processing... 197_img_.png
# processing... 915_img_.png
# processing... 470_img_.png
# processing... 233_img_.png
# processing... 417_img_.png
# processing... 429_img_.png
# processing... 922_img_.png
# processing... 361_img_.png
# processing... 743_img_.png
# processing... 231_img_.png
# processing... 406_img_.png
# processing... 1225.png
# processing... 63_img_.png
# processing... 290_img_.png
# processing... 424_img_.png
# processing... 425_img_.png
# processing... 294_img_.png
# processing... 258_img_.png
# processing... 143_img_.png
# processing... 265_img_.png
# processing... 893_img_.png
# processing... 609_img_.png
# processing... 631_img_.png
# processing... 841.png
# processing... 738_img_.png
# processing... 449_img_.png
# processing... 445_img_.png
# processing... 778_img_.png
# processing... 745_img_.png
# processing... 117_img_.png
# processing... 1491.png
# processing... 570_img_.png
# processing... 567.png
# processing... 831_img_.png
# processing... 124_img_.png
# processing... 854_img_.png
# processing... 681_img_.png
# processing... 11_img_.png
# processing... 392_img_.png
# processing... 650_img_.png
# processing... 342_img_.png
# processing... 573_img_.png
# processing... 222_img_.png
# processing... 784_img_.png
# processing... 378_img_.png
# processing... 363_img_.png
# processing... 149_img_.png
# processing... 178_img_.png
# processing... 728_img_.png
# processing... 180_img_.png
# processing... 594_img_.png
# processing... 818_img_.png
# processing... 259_img_.png
# processing... 873_img_.png
# processing... 78_img_.png
# processing... 655_img_.png
# processing... 764_img_.png
# processing... 121_img_.png
# processing... 577_img_.png
# processing... 478_img_.png
# processing... 326_img_.png
# processing... 182_img_.png
# processing... 446_img_.png
# processing... 359_img_.png
# processing... 694_img_.png
# processing... 920_img_.png
# processing... 2701.png
# processing... 559.png
# processing... 315_img_.png
# processing... 186_img_.png
# processing... 195_img_.png
# processing... 317_img_.png
# processing... 563_img_.png
# processing... 3650.png
# processing... 141_img_.png
# processing... 504_img_.png
# processing... 177_img_.png
# processing... 469_img_.png

# %%
import os
import numpy as np
from metrics import calculate_entropy, calculate_uiqm, calculate_uciqe
import pandas as pd

uibe_pre = '/media/users/leo/workspace/UIE/expri/UIEB'
oceandark_pre = '/media/users/leo/workspace/UIE/expri/OceanDark2_0'

algorithms = ['COLOR', 'FGAN', 'FUSION2', 'OURS', 'RGHS', 'UDCP', 'UGAN', 'ULAP']

# oceandark_image_list = ['67.jpg', '158.jpg']
oceandark_image_list = ['158.jpg']
# uibe_imge_list = ['53_img_.png', '140_img_.png', '287_img_.png', '534_img_.png', '625_img_.png', '661_img_.png', '682_img_.png', '869_img_.png', '913_img_.png', '918_img_.png']
uibe_imge_list = ['140_img_.png', '287_img_.png', '534_img_.png', '625_img_.png', '661_img_.png', '682_img_.png', '869_img_.png', '913_img_.png', '918_img_.png']


color_metrics = []
fgan_metics = []
fusion2_metrics = []
rghs_metrics = []
udcp_metrics = []
ugan_metrics = []
ulap_metrics = []
ours_metrics = []


def raw_result():
    raw_metrics = []
    data_oceandark_pre = '/media/users/leo/workspace/UIE/datasets/OceanDark2_0'
    data_uibe_pre = '/media/users/leo/workspace/UIE/datasets/UIEB_Dataset'
    for image_name in oceandark_image_list:
        image_path = os.path.join(data_oceandark_pre, image_name)
        # print(image_path)
        if os.path.exists(image_path):
            entropy = calculate_entropy(image_path)
            raw_metrics.append(entropy)
    for image_name in uibe_imge_list:
        image_path = os.path.join(data_uibe_pre, image_name)
        # print(image_path)
        if os.path.exists(image_path):
            entropy = calculate_entropy(image_path)
            raw_metrics.append(entropy)
    
    print(raw_metrics)

def cal_result():
    for algorithm in algorithms:
        for image_name in oceandark_image_list:
            image_path = os.path.join(oceandark_pre, algorithm, image_name)
            # print(image_path)
            if os.path.exists(image_path):
                entropy = calculate_uiqm(image_path)
                if algorithm == 'COLOR':
                    color_metrics.append(entropy)
                elif algorithm == 'FGAN':
                    fgan_metics.append(entropy)
                elif algorithm == 'FUSION2':
                    fusion2_metrics.append(entropy)
                elif algorithm == 'OURS':
                    ours_metrics.append(entropy)
                elif algorithm == 'RGHS':
                    rghs_metrics.append(entropy)
                elif algorithm == 'UDCP':
                    udcp_metrics.append(entropy)
                elif algorithm == 'UGAN':
                    ugan_metrics.append(entropy)
                elif algorithm == 'ULAP':
                    ulap_metrics.append(entropy)

        for image_name in uibe_imge_list:
            image_path = os.path.join(uibe_pre, algorithm, image_name)
            # print(image_path)
            if os.path.exists(image_path):
                entropy = calculate_uiqm(image_path)
                if algorithm == 'COLOR':
                    color_metrics.append(entropy)
                elif algorithm == 'FGAN':
                    fgan_metics.append(entropy)
                elif algorithm == 'FUSION2':
                    fusion2_metrics.append(entropy)
                elif algorithm == 'OURS':
                    ours_metrics.append(entropy)
                elif algorithm == 'RGHS':
                    rghs_metrics.append(entropy)
                elif algorithm == 'UDCP':
                    udcp_metrics.append(entropy)
                elif algorithm == 'UGAN':
                    ugan_metrics.append(entropy)
                elif algorithm == 'ULAP':
                    ulap_metrics.append(entropy)

    print(udcp_metrics) 
    print(ulap_metrics)
    print(rghs_metrics)
    print(ugan_metrics)
    print(fgan_metics)
    print(color_metrics)
    print(fusion2_metrics)
    print(ours_metrics)


    # print('color:', color_metrics)
    # print('fgan:', fgan_metics)
    # print('fusion2:', fusion2_metrics)
    # print('rghs:', rghs_metrics)
    # print('udcp:', udcp_metrics)
    # print('ugan:', ugan_metrics)
    # print('ulap', ulap_metrics)
    # print('ours:', ours_metrics)

    # collect all your metrics into a DataFrame
    xcls = pd.DataFrame({
        'color_metrics': color_metrics,
        'fgan_metics': fgan_metics,
        'fusion2_metrics': fusion2_metrics,
        'rghs_metrics': rghs_metrics,
        'udcp_metrics': udcp_metrics,
        'ugan_metrics': ugan_metrics,
        'ulap_metrics': ulap_metrics,
        'ours_metrics': ours_metrics
    })

    xcls.to_csv('xcls_uciqe_metrics.csv', index=False)

# now xcls has columns = your algorithm metrics,
# and each row is the corresponding value (or element) from each metric list/array
# print(xcls)

raw_result()
# Out:
# [7.2191, 7.0457, 7.0846, 6.5601, 6.9342, 7.7039, 7.8365, 6.9202, 7.4089, 7.012]
